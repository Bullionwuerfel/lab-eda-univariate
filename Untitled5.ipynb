# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("asaniczka/uk-optimal-product-price-prediction")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 117M/117M [00:02<00:00, 59.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/asaniczka/uk-optimal-product-price-prediction/versions/3

# %%
import kagglehub
import os

# Download latest version
dataset_path = kagglehub.dataset_download("asaniczka/uk-optimal-product-price-prediction")

# Find the CSV file within the downloaded dataset directory
for filename in os.listdir(dataset_path):
    if filename.endswith(".csv"):
        csv_file_path = os.path.join(dataset_path, filename)
        break  # Stop after finding the first CSV file

# Now use the CSV file path to read the data
import pandas as pd
df = pd.read_csv(csv_file_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
top5=df["category"].value_counts().head(5).index

# %%
list(top5)
# Out:
# ['Sports & Outdoors',
#  'Beauty',
#  'Handmade Clothing, Shoes & Accessories',
#  'Bath & Body',
#  'Birthday Gifts']

# %%
sns.countplot(x='category', data=df[df["category"].isin(top5)])
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
df['category'].value_counts().head(5).plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set3"))
# Out:
# <Axes: ylabel='count'>

# %%
df["price"].describe()
# Out:
# count    2.443651e+06
# mean     8.924381e+01
# std      3.456089e+02
# min      0.000000e+00
# 25%      9.990000e+00
# 50%      1.909000e+01
# 75%      4.599000e+01
# max      1.000000e+05
# Name: price, dtype: float64

# %%
df["price"].describe()["mean"]
# Out:
# 89.24380943923663

# %%
df["price"].describe()["50%"]
# Out:
# 19.09

# %%
df["price"].describe()["std"]**2 #variance
# Out:
# 119445.48532256526

# %%
df["price"].describe()["std"] #stadard deviation
# Out:
# 345.60886175352226

# %%
df["price"].describe()["75%"]-df["price"].describe()["25%"] #interquartile range
# Out:
# 36.0

# %%
sns.histplot(df['price'], kde=True, bins=30, color="salmon")

#the histogramm is ruined by outlier values. 100k pound items on amazon?
#we could delete these items from the dataset
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(data = df['price'], color="lightblue")
# Out:
# <Axes: ylabel='price'>

# %%
mean_rating = df['stars'].mean()
median_rating = df['stars'].median()
mode_rating = df['stars'].mode()[0]

# %%
mean_rating, median_rating, mode_rating
# Out:
# (2.152836472966065, 0.0, 0.0)

# %% [markdown]
# Most commonly the rating is zero. So more than half of all product are rated zero. The rest must be above 4.3, since the average rating is above 2.15

# %%
df["stars"].std(), df["stars"].var(), df["stars"].quantile(0.75)-df["stars"].quantile(0.25)
# Out:
# (2.1948653785054697, 4.81743402976196, 4.4)

# %% [markdown]
# ratings are basically either 0 or 5 stars,rarely anything nuanced on between

# %%
df["stars"].skew(), df["stars"].kurtosis()
# Out:
# (0.08120735761080985, -1.9260061280432985)

# %% [markdown]
# the ratings tend to bunch at the limits

# %%
sns.histplot(df['stars'], kde=True, bins=50, color="salmon")
# Out:
# <Axes: xlabel='stars', ylabel='Count'>

# %% [markdown]
# Report: UK Product Pricing and Ratings Analysis
# This report summarizes an exploratory data analysis of UK product pricing and ratings.
#
# Product Categories: The top 5 product categories were identified, revealing the most popular product types in the UK market.
#
# Product Pricing:
#
# Prices exhibit a skewed distribution with potential outliers (very high-priced items).
# Descriptive statistics (mean, median, standard deviation, etc.) were calculated to understand price distribution.
# Outliers require further investigation and potential handling.
# Product Ratings:
#
# Ratings tend to be either 0 or 5 stars, lacking granularity.
# Most products have a rating of 0.
# Distribution analysis (histogram, skewness, kurtosis) confirmed this pattern.
# Key Insights:
#
# Top product categories were identified.
# Price distribution is skewed with outliers.
# Ratings are concentrated at extremes (0 or 5).
# Further Analysis:
#
# Address price outliers.
# Analyze price and ratings within specific categories.
# Explore correlations between price, ratings, and other attributes.
# Consider predictive modeling for price or rating forecasting.
